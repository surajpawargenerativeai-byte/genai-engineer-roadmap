# %%
import torch

# %%
X = torch.tensor([
    [25,50000,2000,1],
    [40,80000,5000,0],
    [30,60000,3000,2],
    [50,90000,7000,1]
])

# %%
y = torch.tensor([0,1,0,1])

# %%
print("Number of samples:", X.shape[0])
# Out:
# Number of samples: 4

# %%
print("Number of features:", X.shape[1])
# Out:
# Number of features: 4

# %%
print("Shape of X:", X.shape)
# Out:
# Shape of X: torch.Size([4, 4])

# %%
print("Shape of y:", y.shape)
# Out:
# Shape of y: torch.Size([4])

# %%
print("Sample 2:", X[1])
# Out:
# Sample 2: tensor([   40, 80000,  5000,     0])

# %%
print("Label 2:", y[1])
# Out:
# Label 2: tensor(1)
