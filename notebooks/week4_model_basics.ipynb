# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
from torch import nn

# %%
class CreditNet(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return x

# %%
model = CreditNet()
print(model)
# Out:
# CreditNet()

# %%
x = torch.tensor([
    [50000.0, 29.0, 10000.0, 1.0],
    [70000.0, 31.0, 7000.0, 0.0]
])

print(x.shape)
# Out:
# torch.Size([2, 4])

# %%
output = model(x)
print(output)
print(output.shape)
# Out:
# tensor([[5.0000e+04, 2.9000e+01, 1.0000e+04, 1.0000e+00],
#         [7.0000e+04, 3.1000e+01, 7.0000e+03, 0.0000e+00]])
# torch.Size([2, 4])
