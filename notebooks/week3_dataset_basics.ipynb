# %%
import torch

# %%
X = torch.tensor([
    [50000.0, 29.0, 10000.0],
    [30000.0, 45.0, 15000.0],
    [90000.0, 35.0, 5000.0]
])

# %%
y = torch.tensor([0,1,0])

# %%
print("Features:")
print(X)
print("Shape of X: ", X.shape)

print("\nLabels:")
print(y)
print("Shape of y:", y.shape)
# Out:
# Features:
# tensor([[5.0000e+04, 2.9000e+01, 1.0000e+04],
#         [3.0000e+04, 4.5000e+01, 1.5000e+04],
#         [9.0000e+04, 3.5000e+01, 5.0000e+03]])
# Shape of X:  torch.Size([3, 3])
#
# Labels:
# tensor([0, 1, 0])
# Shape of y: torch.Size([3])

# %%
print("First sample:", X[0])
print("First label:", y[0])

print("Second sample:", X[1])
print("Second label:", y[1])
# Out:
# First sample: tensor([5.0000e+04, 2.9000e+01, 1.0000e+04])
# First label: tensor(0)
# Second sample: tensor([30000.,    45., 15000.])
# Second label: tensor(1)
