# %%
import torch

# %%
scalar = torch.tensor(5)

# %%
print(scalar)
# Out:
# tensor(5)

# %%
print(scalar.shape)
# Out:
# torch.Size([])

# %%
print(scalar.ndim)
# Out:
# 0

# %%
vector = torch.tensor([1,2,3,4])

# %%
print(vector)
# Out:
# tensor([1, 2, 3, 4])

# %%
print(vector.shape)
# Out:
# torch.Size([4])

# %%
print(vector.ndim)
# Out:
# 1

# %%
matrix = torch.tensor([[1,2], [3,4], [5,6]])

# %%
print(matrix)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
print(matrix.shape)
# Out:
# torch.Size([3, 2])

# %%
print(matrix.ndim)
# Out:
# 2

# %%
tensor_3d = torch.tensor([
    [[1,2], [3,4]],
    [[5,6], [7,8]]
])

# %%
print(tensor_3d)
# Out:
# tensor([[[1, 2],
#          [3, 4]],
#
#         [[5, 6],
#          [7, 8]]])

# %%
print(tensor_3d.shape)
# Out:
# torch.Size([2, 2, 2])

# %%
print(tensor_3d.ndim)
# Out:
# 3

# %%
x = torch.tensor([1,2,3])

y = torch.tensor([1.0, 2.0, 3.0])

print(x.dtype)
print(y.dtype)
# Out:
# torch.int64
# torch.float32

# %%
zeros = torch.zeros((2,3))

ones = torch.ones((2,3))

random_tensor = torch.rand((2,3))

print(zeros)
print(ones)
print(random_tensor)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# tensor([[0.6404, 0.9859, 0.5343],
#         [0.8583, 0.6531, 0.8598]])
